# %% [markdown]
# #3.1 Homework
#
# 1. What is an algorithm?
# a set of instructions to be executed in a certain order to get the desired outpu
#
# 2. Variable names may not start with certain characters - name two.
# Digit
# Underscore
#
# 3. What is a Semantic error?
# hen a program works without raising an Exception, but gives a different than the expected result.
#
# 4. What is the #1 rule of coding / debugging?
# Read the errors
#
#
# 5. List 5 Python reserved words.
# and
# as
# except
# While
# yield

# %%
me = """Brandy Fletcher\

Nectarines\

Sr Data Analyst"""

print(me)
# Out:
# Brandy Fletcher
# Nectarines
# Sr Data Analyst

# %%
m = "Dryer, Flat Irons, Shampoo Bowl, Clips, Combs"
print(m)

n = str( 'How am I doing so far?')
print(n)

t1 = ("Chili Peppers", "Garlic", "Black Pepper", "Scotch Bonnet", "Paprika","Rosemary")
print(t1)

I = {"name" : "Brandy", "age" : 38}
print(I)

g = int('619')
print(g)

listLength = len(n)
print("size of the list =..",listLength)

print("Element at index 4:", n[4])
# Out:
# Dryer, Flat Irons, Shampoo Bowl, Clips, Combs
# How am I doing so far?
# ('Chili Peppers', 'Garlic', 'Black Pepper', 'Scotch Bonnet', 'Paprika', 'Rosemary')
# {'name': 'Brandy', 'age': 38}
# 619
# size of the list =.. 22
# Element at index 4: a

# %%
Savvy= str("Learning Data Analytics and Python is Awesome!")
print(Savvy)
# Out:
# Learning Data Analytics and Python is Awesome!

# %%
Savvy= str("Learning Data Analytics and Python is Awesome!")
print(Savvy)


print(Savvy[5:-22])
# Out:
# Learning Data Analytics and Python is Awesome!
# ing Data Analytics

# %%
Savvy= str("Learning Data Analytics and Python is Awesome!")
print(Savvy)

j = "great"
print(Savvy.replace("Awesome", j))
# Out:
# Learning Data Analytics and Python is Awesome!
# Learning Data Analytics and Python is great!

# %%
minibio = "Hi my name is {name}, I am {tall} and {so} old today"
print(minibio.format(name = "Brandy", tall = "5 ft 5" , so = 38))
       
b = float(38)
print(b)
# Out:
# Hi my name is Brandy, I am 5 ft 5 and 38 old today
# 38.0

# %%
# 3.2 Homework

# %%
# Create a list of at least 5 elements of mixed data types

T = ["Dryer", "Chili Pepper", 3, 7.5, "Shelly"]
print(T)

print("\nSecond name ... ", T[1])

T[1] = "Roger"
print("2nd name replaced ... ", T)

  # - Append or insert several more items to the list
T = ["Dryer", "Chili Pepper", 3, 7.5, "Shelly"]
T.append("orange")
print("New list ... ", T)

#  Find and print the length of the list
print("The length of T is ... ", len(T))

#  Slice a sub-section of the 1st list,  
 
T = ["Dryer", "Chili Pepper", 3, 7.5, "Shelly"]
print(T[-2:5])

# save it to a different 2nd list
SA = [7.5, "Shelly",  "Garlic", "Black Pepper"]
print(SA)


#  Extend your original list with the 2nd list sliced above
T = ["Dryer", "Chili Pepper", 3, 7.5, "Shelly"]
SA = [7.5, "Shelly",  "Garlic", "Black Pepper"]
T.extend(SA)
print("Extended T...", T)




#  Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean
simlist = [23, 58, 6, 19, 84]


# Sort "simList", and print the list
simlist.sort(reverse=True)
print("Sorted numbers in reverse - ", simlist)

# - Copy the "simList" list to another 3rd list

NEW_sim = "simlist"
NEW_sim = simlist.copy()
print('Copied List:', NEW_sim)


#add the 2nd and 3rd lists together into a 4th list
simlist = [23, 58, 6, 19, 84]
simlist.sort(reverse=True)
print("Sorted numbers in reverse - ", simlist)

NEW_sim = "simlist"
NEW_sim = simlist.copy()
print('Copied List:', NEW_sim)

B = [84, 58, 23, 19, 6]
B.append(NEW_sim)
print(B)




# # 11. Create a tuple of about 5 elements
#     - Multiply your tuple by 3 and save it to a new 2nd tuple
s = ("rabbit", "fox", "dog", "cat", "mule")
print(s*3)

# # #     - Access and print the 12th element from the 2nd tuple 
# There were 5 items in the original tuple. Multiplied by 3 = 15. 12th item in list is "DOG"
s2 = ('rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule')
print("\ns2[12] ... ", s2[12])

# #     - Sort the 2nd tuple and print it

s_2 = ["rabbit","fox","dog","cat","mule","rabbit","fox","dog","cat","mule","rabbit","fox","dog", "cat", "mule"]
s_2.sort()
print(s_2)



# <br>

# #     - Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
s2 = ('rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule') 
L = s2[3]
U = s2[1]
V = s2[9] 
S = s2[6]
print(L,U,V,S)
#  #     - Unpack the 3rd tuple into 4 variables and print these variables
CAT = "box"
FOX = "tools"
MULE = "plug"
FOX2 = "orange"
print(CAT,FOX,MULE,FOX2)

# #     - Create a 4th tuple with single item 50 and print this tuple
W = 50,
print(W)

# #     - Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple
s2 = ('rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule') 
s_2 = ["rabbit","fox","dog","cat","mule","rabbit","fox","dog","cat","mule","rabbit","fox","dog", "cat", "mule"]

s2 = ('rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule')  
s3 = (L,U,V,S)

tuple3 = s2 + s3
print(tuple3)

b2 = {"white", "purple", "red"}
print(b2)

b2 = {"white", "purple", "red"}
b2.add("orange, grapefruit")
print(b2)

b2.add("car")
print(b2)

bset = {"pickles", "diapers", "sock"}

b3 = b2.union(bset)
print(b3)

bset = {"pickles", "diapers", "sock"}
bset.pop()
print(bset)

b2 = {"white", "purple", "red"}
b2.clear()
print(b2)

bset.discard("sock")
print(bset)
# 13. Create a dictionary with at least 5 values of different data types
this= {
  "brand": "Acura",
  "model": "ILX",
  "year": 2013,
  "license": "Y",
  "color": "Black"
}
print("brand")


this.update({'year':150})  
print("Updated inventory:",this)  


this= {
  "brand": "Acura",
  "model": "ILX",
  "year": 2013,
  "license": "Y",
  "color": "Black"
}
this[s3] = (L,U,V,S)
print(this)


this = list(this)
print(this)

this= {
  "brand": "Acura",
  "model": "ILX",
  "year": 2013,
  "license": "Y",
  "color": "Black"
}

for x in this:
  print(this[x])
dict = this.copy()
print(dict)


myKeys =this.keys()
print("\nPrinting my Keys ... \n", myKeys)
myvalues =dict.values()
print("nPrinting my values...\n", myvalues)



dict = {"brand": "Acura",
  "model": "ILX",
  "year": 2013,
  "license": "Y",
  "color":"Black"
  }
dict.pop("color")
print(dict)


dict.clear()
print(dict)
# Out:
# ['Dryer', 'Chili Pepper', 3, 7.5, 'Shelly']
#
# Second name ...  Chili Pepper
# 2nd name replaced ...  ['Dryer', 'Roger', 3, 7.5, 'Shelly']
# New list ...  ['Dryer', 'Chili Pepper', 3, 7.5, 'Shelly', 'orange']
# The length of T is ...  6
# [7.5, 'Shelly']
# [7.5, 'Shelly', 'Garlic', 'Black Pepper']
# Extended T... ['Dryer', 'Chili Pepper', 3, 7.5, 'Shelly', 7.5, 'Shelly', 'Garlic', 'Black Pepper']
# Sorted numbers in reverse -  [84, 58, 23, 19, 6]
# Copied List: [84, 58, 23, 19, 6]
# Sorted numbers in reverse -  [84, 58, 23, 19, 6]
# Copied List: [84, 58, 23, 19, 6]
# [84, 58, 23, 19, 6, [84, 58, 23, 19, 6]]
# ('rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule', 'rabbit', 'fox', 'dog', 'cat', 'mule')
#
# s2[12] ...  dog
# ['cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'fox', 'fox', 'fox', 'mule', 'mule', 'mule', 'rabbit', 'rabbit', 'rabbit']
# cat fox mule fox
# box tools plug orange
# (50,)
# ...
